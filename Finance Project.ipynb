# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Finance Data Project
#
# In this data project we will focus on exploratory data analysis of stock prices. Keep in mind, this project is just meant to practice your visualization and pandas skills, it is not meant to be a robust financial analysis or be taken as financial advice.
# ____
# ** NOTE: This project is extremely challenging because it will introduce a lot of new concepts and have you looking things up on your own (we'll point you in the right direction) to try to solve the tasks issued. Feel free to just go through the solutions lecture notebook and video as a "walkthrough" project if you don't want to have to look things up yourself. You'll still learn a lot that way! **
# ____
# We'll focus on bank stocks and see how they progressed throughout the [financial crisis](https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308) all the way to early 2016.

# %% [markdown]
# ## Get the Data
#
# In this section we will learn how to use pandas to directly read data from Google finance using pandas!
#
# First we need to start with the proper imports, which we've already laid out for you here.
#
# *Note: [You'll need to install pandas-datareader for this to work!](https://github.com/pydata/pandas-datareader) Pandas datareader allows you to [read stock information directly from the internet](http://pandas.pydata.org/pandas-docs/stable/remote_data.html) Use these links for install guidance (**pip install pandas-datareader**), or just follow along with the video lecture.*
#
# ### The Imports
#
# Already filled out for you.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
sns.set(style="whitegrid")
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.32.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Data
#
# We need to get data using pandas datareader. We will get stock information for the following banks:
# * Bank of America: BAC
# * Citigroup: C
# * Goldman Sachs: GS
# * JPMorgan Chase: JPM
# * Morgan Stanley: MS
# * Wells Fargo: WFC
#
# **Figure out how to get the stock data from Jan 1st 2006 to Jan 1st 2016 for each of these banks. Set each bank to be a separate dataframe, with the variable name for that bank being its ticker symbol.**

# %%
yf.download('BAC',start='2006-01-01',end='2016-01-01').to_csv("E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/BAC_stock.csv")

BAC = pd.read_csv("E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/BAC_stock.csv")

BAC.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2006-01-03  46.919998  47.180000  46.150002  47.080002  31.750578  16296700
# 1  2006-01-04  47.000000  47.240002  46.450001  46.580002  31.413359  17757900
# 2  2006-01-05  46.580002  46.830002  46.320000  46.639999  31.453823  14970700
# 3  2006-01-06  46.799999  46.910000  46.349998  46.570000  31.406624  12599800
# 4  2006-01-09  46.720001  46.970001  46.360001  46.599998  31.426865  15619400

# %%
yf.download('C',start='2006-01-01',end='2016-01-01').to_csv("E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/C_stock.csv")

C = pd.read_csv("E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/C_stock.csv")

C.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2006-01-03  490.000000  493.799988  481.100006  492.899994  329.149933
# 1  2006-01-04  488.600006  491.000000  483.500000  483.799988  323.073059
# 2  2006-01-05  484.399994  487.799988  484.000000  486.200012  324.675812
# 3  2006-01-06  488.799988  489.000000  482.000000  486.200012  324.675812
# 4  2006-01-09  486.000000  487.399994  483.000000  483.899994  323.139984
#
#     Volume
# 0  1537600
# 1  1870960
# 2  1143160
# 3  1370210
# 4  1680740

# %%
yf.download('GS',start='2006-01-01',end='2016-01-01').to_csv("E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/GS_stock.csv")

GS = pd.read_csv("E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/GS_stock.csv")

GS.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#          Date        Open        High         Low       Close  Adj Close  \
# 0  2006-01-03  126.699997  129.440002  124.230003  128.869995  96.809433
# 1  2006-01-04  127.349998  128.910004  126.379997  127.089996  95.472244
# 2  2006-01-05  126.000000  127.320000  125.610001  127.040001  95.434708
# 3  2006-01-06  127.290001  129.250000  127.290001  128.839996  96.786880
# 4  2006-01-09  128.500000  130.619995  128.000000  130.389999  97.951271
#
#     Volume
# 0  6188700
# 1  4861600
# 2  3717400
# 3  4319600
# 4  4723500

# %%
yf.download('JPM',start='2006-01-01',end='2016-01-01').to_csv("E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/JPM_stock.csv")

JPM = pd.read_csv("E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/JPM_stock.csv")

JPM.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2006-01-03  39.830002  40.360001  39.299999  40.189999  24.516226  12838600
# 1  2006-01-04  39.779999  40.139999  39.419998  39.619999  24.374731  13491500
# 2  2006-01-05  39.610001  39.810001  39.500000  39.740002  24.448565   8109400
# 3  2006-01-06  39.919998  40.240002  39.549999  40.020000  24.620821   7966900
# 4  2006-01-09  39.880001  40.720001  39.880001  40.669998  25.020712  16575200

# %% [markdown]
# ** Create a list of the ticker symbols (as strings) in alphabetical order. Call this list: tickers**

# %%
yf.download('MS',start='2006-01-01',end='2016-01-01').to_csv("E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/MS_stock.csv")

MS = pd.read_csv("E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/MS_stock.csv")

MS.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2006-01-03  57.169998  58.490002  56.740002  58.310001  32.661316  5377000
# 1  2006-01-04  58.700001  59.279999  58.349998  58.349998  32.683712  7977800
# 2  2006-01-05  58.549999  58.590000  58.020000  58.509998  32.773335  5778000
# 3  2006-01-06  58.770000  58.849998  58.049999  58.570000  32.806942  6889800
# 4  2006-01-09  58.630001  59.290001  58.619999  59.189999  33.154232  4144500

# %%
yf.download('WFC',start='2006-01-01',end='2016-01-01').to_csv("E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/WFC_stock.csv")

WFC = pd.read_csv("E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/WFC_stock.csv")

WFC.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2006-01-03  31.600000  31.975000  31.195000  31.900000  18.979551  11016400
# 1  2006-01-04  31.799999  31.820000  31.365000  31.530001  18.759417  10870000
# 2  2006-01-05  31.500000  31.555000  31.309999  31.495001  18.738594  10158000
# 3  2006-01-06  31.580000  31.775000  31.385000  31.680000  18.848658   8403800
# 4  2006-01-09  31.674999  31.825001  31.555000  31.674999  18.845676   5619600

# %% [markdown]
# **Use pd.concat to concatenate the bank dataframes together to a single data frame called bank_stocks. Set the keys argument equal to the tickers list. Also pay attention to what axis you concatenate on.**

# %%
tickers = ['BAC','C','GS','MS','JPM','WFC']

# %%
bank_stocks= pd.concat([BAC,C,GS,MS,JPM,WFC],axis=1,keys = tickers)

bank_stocks = bank_stocks.round(2)

bank_stocks.to_csv("E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/bank_stocks.csv")

# %% [markdown]
# **Set the column name levels (this is filled out for you):**

# %%
bank_stocks.columns.names = ['Bank Ticker','Stock Info']

# %% [markdown]
# **Check the head of the bank_stocks dataframe.**

# %%
bank_stocks.head()
# Out:
# Bank Ticker         BAC                                                  \
# Stock Info         Date   Open   High    Low  Close Adj Close    Volume
# 0            2006-01-03  46.92  47.18  46.15  47.08     31.75  16296700
# 1            2006-01-04  47.00  47.24  46.45  46.58     31.41  17757900
# 2            2006-01-05  46.58  46.83  46.32  46.64     31.45  14970700
# 3            2006-01-06  46.80  46.91  46.35  46.57     31.41  12599800
# 4            2006-01-09  46.72  46.97  46.36  46.60     31.43  15619400
#
# Bank Ticker           C                ...    JPM                      \
# Stock Info         Date   Open   High  ...  Close Adj Close    Volume
# 0            2006-01-03  490.0  493.8  ...  40.19     24.52  12838600
# 1            2006-01-04  488.6  491.0  ...  39.62     24.37  13491500
# 2            2006-01-05  484.4  487.8  ...  39.74     24.45   8109400
# 3            2006-01-06  488.8  489.0  ...  40.02     24.62   7966900
# ...

# %% [markdown]
# # EDA
#
# Let's explore the data a bit! Before continuing, I encourage you to check out the documentation on [Multi-Level Indexing](http://pandas.pydata.org/pandas-docs/stable/advanced.html) and [Using .xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html).
# Reference the solutions if you can not figure out how to use .xs(), since that will be a major part of this project.
#
# **What is the max Close price for each bank's stock throughout the time period?**

# %%
BAC_Max = bank_stocks['BAC']['Close'].max()

print('BAC:',BAC_Max)

C_Max = bank_stocks['C']['Close'].max()

print('C:',C_Max)

GS_Max = bank_stocks['GS']['Close'].max()

print('GS:',GS_Max)

JPM_Max = bank_stocks['JPM']['Close'].max()

print('JPM:',JPM_Max)

WFC_Max = bank_stocks['WFC']['Close'].max()

print('WFC:',WFC_Max)
# Out:
# BAC: 54.9
# C: 564.1
# GS: 247.92
# JPM: 70.08
# WFC: 58.52

# %% [markdown]
# **Create a new empty DataFrame called returns. This dataframe will contain the returns for each bank's stock. returns are typically defined by:**
#
# $$r_t = \frac{p_t - p_{t-1}}{p_{t-1}} = \frac{p_t}{p_{t-1}} - 1$$

# %%
returns = pd.DataFrame()

for t2 in tickers:
    returns[t2+' return'] = bank_stocks[t2]['Close'].pct_change()
    returns['Date'] = bank_stocks[t2]['Date']

# %%
returns.to_csv('E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/returns.csv')

# %%
returns_file = pd.read_csv('E:/Refactored_Py_DS_ML_Bootcamp-master/10-Data-Capstone-Projects/returns.csv')

returns_file['Date'] = pd.to_datetime(returns_file['Date'])

returns_file.set_index('Date', inplace=True)

returns_file.head()
# Out:
#             BAC return  C return  GS return  MS return  JPM return  WFC return
# Date
# 2006-01-03    0.000000  0.000000   0.000000   0.000000    0.000000    0.000000
# 2006-01-04   -0.010620 -0.018462  -0.013812   0.000686   -0.014183   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393   0.002742    0.003029   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169   0.001025    0.007046    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030   0.010586    0.016242   -0.000316

# %% [markdown]
# **Create a pairplot using seaborn of the returns dataframe. What stock stands out to you? Can you figure out why?**

# %%
pr = sns.PairGrid(returns_file, height=2.5, aspect=1.5)

# Diagonal plots (histograms)
pr.map_diag(sns.histplot, color='skyblue', edgecolor='black')

# Upper triangle (scatter plots)
pr.map_upper(sns.scatterplot, color='purple', alpha=0.7)

# Lower triangle (KDE plots with filled contours)
pr.map_lower(sns.scatterplot, color='green', alpha=0.7)

plt.show()

# %% [markdown]
# **Using this returns DataFrame, figure out on what dates each bank stock had the best and worst single day returns. You should notice that 4 of the banks share the same day for the worst drop, did anything significant happen that day?**

# %%
returns_file.idxmin()
# Out:
# BAC return   2009-01-20
# C return     2009-02-27
# GS return    2009-01-20
# MS return    2008-10-09
# JPM return   2009-01-20
# WFC return   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# **You should have noticed that Citigroup's largest drop and biggest gain were very close to one another, did anythign significant happen in that time frame?**

# %%
returns_file.idxmax()
# Out:
# BAC return   2009-04-09
# C return     2008-11-24
# GS return    2008-11-24
# MS return    2008-10-13
# JPM return   2009-01-21
# WFC return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# **Take a look at the standard deviation of the returns, which stock would you classify as the riskiest over the entire time period? Which would you classify as the riskiest for the year 2015?**

# %%
returns_file.std()
# Out:
# BAC return    0.036640
# C return      0.038664
# GS return     0.025385
# MS return     0.037812
# JPM return    0.027662
# WFC return    0.030232
# dtype: float64

# %%
year_2015 = returns_file.loc['2015']

year_2015.std()

## MS return: 0.016249 is the riskiest over 2015 but all are closer
# Out:
# BAC return    0.016163
# C return      0.015289
# GS return     0.014046
# MS return     0.016249
# JPM return    0.014017
# WFC return    0.012591
# dtype: float64

# %% [markdown]
# **Create a distplot using seaborn of the 2015 returns for Morgan Stanley**

# %%
MS_dist_2015 = returns_file.loc['2015']['MS return']

sns.displot(data=MS_dist_2015,bins=100,kde=True,color='#1679AB',height=6.7,aspect=1.3)

plt.show()

# %% [markdown]
# **Create a distplot using seaborn of the 2008 returns for CitiGroup**

# %%
C_dist_2008 = returns_file.loc['2008']['C return']

sns.displot(data=C_dist_2008,bins = 100,color='#8E7AB5',kde =True,height=6.7,aspect=1.3)

plt.show()

# %% [markdown]
# ____
# # More Visualization
#
# A lot of this project will focus on visualizations. Feel free to use any of your preferred visualization libraries to try to recreate the described plots below, seaborn, matplotlib, plotly and cufflinks, or just pandas.

# %% [markdown]
# **Create a line plot showing Close price for each bank for the entire index of time. (Hint: Try using a for loop, or use [.xs](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.xs.html) to get a cross section of the data.)**

# %%
# Define the list of tickers
tickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# Download again the data for all tickers in the specified date range because the data in the first doesn't file the requirements
bank_stocks2 = yf.download(tickers, start='2006-01-01', end='2016-01-01')
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
Closes_Prices = bank_stocks2['Close']

# Convert the datetime index to strings to avoid the deprecation warning
Closes_Prices.index = Closes_Prices.index.astype(str)

Closes_Prices.iplot()

plt.show()
# Out:
# <div>                            <div id="fcfd353f-542b-4290-9574-8e60eede3761" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# ## Moving Averages
#
# Let's analyze the moving averages for these stocks in the year 2008.
#
# **Plot the rolling 30 day average against the Close Price for Bank Of America's stock for the year 2008**

# %%
# Creating a Close graph for BAC in 2008
BAC_Close_2008 = bank_stocks2.loc['2008']['Close']['BAC']

# Creating a 30-day moving average for BAC in 2008
AVG_2008 = bank_stocks2.loc['2008']['Close'].rolling(window=30).mean()
BAC_AVG_2008 = AVG_2008['BAC']

# Convert the datetime index to strings to avoid the deprecation warning
BAC_Close_2008.index = BAC_Close_2008.index.astype(str)
BAC_AVG_2008.index = BAC_AVG_2008.index.astype(str)

# Combine both the closing prices and the moving average into one DataFrame
combined_df = pd.DataFrame({
    'BAC Close (2008)': BAC_Close_2008,
    'BAC 30-Day Moving Avg (2008)': BAC_AVG_2008
})

# Plot both on the same interactive graph using iplot
combined_df.iplot(title='BAC Closing Prices and 30-Day Moving Average (2008)',
                  xTitle='Date',
                  yTitle='Price',
                  colors=['darkblue', 'green'])
# Out:
# <div>                            <div id="d0904400-51e2-4102-a147-49762904db71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **Create a heatmap of the correlation between the stocks Close Price.**

# %%
## Create a correaltin matrix variable for all tickers
corr_matrix = bank_stocks2['Close'].corr()

plt.figure(figsize=(12, 8)) ## Increase the size of the graph

## Create a heatmap corr. for all tickers
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Add title
plt.title('Correlation of Bank Stock Closing Prices (2006-2016)', fontsize=16, fontweight='bold',y=1.05,color='darkblue')

# Add x_label
plt.xlabel('Ticker', fontweight='bold')

# Add y_label
plt.ylabel('Ticker', fontweight='bold')

plt.show()

# %% [markdown]
# **Optional: Use seaborn's clustermap to cluster the correlations together:**

# %%
plt.figure(figsize=(12, 8)) ## Increase the size of the graph

## Create a heatmap corr. for all tickers
sns.clustermap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

plt.show()

# %% [markdown]
# # Part 2 (Optional)
#
# In this second part of the project we will rely on the cufflinks library to create some Technical Analysis plots. This part of the project is experimental due to its heavy reliance on the cuffinks project, so feel free to skip it if any functionality is broken in the future.

# %% [markdown]
# **Use .iplot(kind='candle) to create a candle plot of Bank of America's stock from Jan 1st 2015 to Jan 1st 2016.**

# %%
## Creating a tickers data for a specified year['2015']
tickers_2015 = bank_stocks2[['Open', 'High', 'Low', 'Close']].loc['2015']

## limiting the data to include only 'BAC' data by using : to select all rows in the DataFrame for the year 2015 and with (slice(None),'BAC') that means "select all values" for the first level of this coming column index.
BAC_2015 = tickers_2015.loc[:,(slice(None),'BAC')]

## adding the columns for the new variable
BAC_2015.columns = ['Open', 'High', 'Low', 'Close']

BAC_2015
# Out:
#                  Open       High        Low      Close
# Date
# 2015-01-02  17.990000  18.030001  17.680000  17.900000
# 2015-01-05  17.790001  17.809999  17.290001  17.379999
# 2015-01-06  17.420000  17.440001  16.780001  16.860001
# 2015-01-07  17.139999  17.180000  16.870001  16.940001
# 2015-01-08  17.160000  17.340000  17.100000  17.290001
# ...               ...        ...        ...        ...
# 2015-12-24  17.320000  17.379999  17.219999  17.270000
# 2015-12-28  17.219999  17.230000  16.980000  17.129999
# 2015-12-29  17.250000  17.350000  17.160000  17.280001
# 2015-12-30  17.200001  17.240000  17.040001  17.049999
# 2015-12-31  17.010000  17.070000  16.830000  16.830000
#
# [252 rows x 4 columns]

# %%
# Convert the datetime index to strings to avoid the deprecation warning
BAC_2015.index = BAC_2015.index.astype(str)

BAC_2015.iplot()
# Out:
# <div>                            <div id="78665b8e-5313-4f73-92c5-b37ef9cf2b23" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **Use .ta_plot(study='sma') to create a Simple Moving Averages plot of Morgan Stanley for the year 2015.**

# %%
MS_2015 = bank_stocks2['Close']['MS'].loc['2015']

# Convert the datetime index to strings to avoid the deprecation warning
MS_2015.index = MS_2015.index.astype(str)

MS_2015.ta_plot(study='sma')
# Out:
# <div>                            <div id="23d4c74a-a184-4b1e-8a3b-8789c90bcf80" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# **Use .ta_plot(study='boll') to create a Bollinger Band Plot for Bank of America for the year 2015.**

# %%
BAC_2015 = bank_stocks2['Close']['BAC'].loc['2015']

# Convert the datetime index to strings to avoid the deprecation warning
BAC_2015.index = BAC_2015.index.astype(str)

BAC_2015.ta_plot(study='boll')
# Out:
# <div>                            <div id="4ea07512-ab73-4bd6-bf5d-277a37474aa7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
